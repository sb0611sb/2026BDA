# %% [markdown]
# <a href="https://colab.research.google.com/github/sb0611sb/2026BDA/blob/main/w09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 49.1 MB/s eta 0:00:00
# ...

# %%
# !pip install pydataset
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 66.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939415 sha256=269401c6472f8b9b21f16c96f3c1766fdf3aa57740df57f77ff87e71ed8d6dc0
#   Stored in directory: /root/.cache/pip/wheels/4c/82/ad/f04abc617222b10438b1285ab9b5cfaecd180c10a7c81cff54
# Successfully built pydataset
# ...

# %%
from matplotlib import figure
import koreanize_matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from  pydataset import data
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize']=(5,3)
# Out:
# initiated datasets repo at: /root/.pydataset/

# %%
plt.scatter([3,5],[7,10])
plt.show()

# %%
plt.scatter(range(1,5),range(5,9))
plt.show()

# %%
tg = data('ToothGrowth')

sns.scatterplot(data=tg, x='dose', y='len', hue='supp')
plt.title('correlation between dose and length')
plt.xlabel('dose')
plt.ylabel('len')
plt.show()

# %%
sns.boxplot(data=tg,x='dose',y='len',hue='supp')
sns.stripplot(data=tg,x='dose',y='len',hue='supp',dodge=True,alpha=0.6)
plt.title('tooth growth by dose and supplement')
plt.xlabel('len')
plt.ylabel('dose')
plt.legend(title='supp')
plt.tight_layout()
plt.show()

# %%
airpg = data('AirPassengers')

plt.plot(airpg.time, airpg.AirPassengers, color='darkgreen')
plt.title('Air Passengers')
plt.xlabel('time')
plt.ylabel('passengers')
plt.show()

# %%
x=[1,2,3,4]
y1=[1,4,9,16]
y2=[2,4,6,8]
y3=[3,6,9,12]
y4=[4,8,12,16]

plt.plot(x,y1,linestyle='-',label='soild')
plt.plot(x,y2,linestyle='--',label='dash')
plt.plot(x,y3,linestyle=':',label='Dot')
plt.plot(x,y4,linestyle='-.',label='dash dot')
plt.legend()
plt.show()

# %%
x=[1,2,3,4]
y1=[1,4,9,16]
y2=[2,4,6,8]
y3=[3,6,9,12]
y4=[4,8,12,16]
y5=[3,1,4,2]

plt.plot(x,y1,marker='o', label='circle')
plt.plot(x,y2,marker='^', label='triangle')
plt.plot(x,y3,marker='s', label='sqare')
plt.plot(x,y4,marker='*', label='star')
plt.plot(x,y5,marker=',', label='pixel')
plt.legend()
plt.show()

# %%
vc = tg[tg.supp=='VC'][['len','dose']]
oj = tg[tg.supp=='OJ'][['len','dose']]

plt.plot(vc.dose, vc.len, color='cyan',marker='o',lw=.7)
plt.plot(oj.dose, oj.len, color='deeppink',marker='^',lw=.7, alpha=.5)
plt.title('tooth growth by dose and supplement')
plt.xlabel('dose')
plt.ylabel('length')
plt.legend(['VC','OJ'],loc='lower right')
plt.show()

# %%
point=[99,65,79,80,90]
name=['a','b','c','d','e']
plt.bar(name,point,color=['blue','chartreuse','purple','grey','orange'])
plt.show()

# %%
plt.barh(name,point,color=['blue','chartreuse','purple','grey','orange'])
plt.show()

# %%
lc = data('LifeCycleSavings')
df=lc[:5][['pop15']]

# %%
plt.bar(df.index,df.pop15)
plt.title('population')
plt.xlabel('country')
plt.ylabel('population')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(data=lc,x='dpi',y='sr',hue='pop15', palette='viridis',size='pop75',sizes=(20,200))
plt.title('savings ratio income and age structure')
plt.xlabel('dpi')
plt.ylabel('sr')
plt.tight_layout()
plt.show()

# %%
mtc = data('mtcars')
mtcc = mtc.cyl.value_counts()

# %%
plt.bar(mtcc.index, mtcc)
plt.title('cars by cylinders')
plt.xlabel('cylinders')
plt.ylabel('cars')
plt.show()

# %%
sns.countplot(mtc, x='gear')
plt.show()

# %%
iris = data('iris')
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
iris.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
n,bins,patches = plt.hist(iris['Sepal.Length'],bins=20,color='yellowgreen',edgecolor='black')
print(n)
print(bins)
print(patches)
plt.show()
# Out:
# [ 4.  5.  7. 16.  9.  5. 13. 14. 10.  6. 10. 16.  7. 11.  4.  2.  4.  1.
#   5.  1.]
# [4.3  4.48 4.66 4.84 5.02 5.2  5.38 5.56 5.74 5.92 6.1  6.28 6.46 6.64
#  6.82 7.   7.18 7.36 7.54 7.72 7.9 ]
# <BarContainer object of 20 artists>

# %%
n,bins,patches = plt.hist(iris['Sepal.Length'],bins=20,color='yellowgreen',edgecolor='white')
for i in range(len(patches)):
  patches[i].set_facecolor(plt.cm.viridis(n[i]/max(n)))

plt.show()

# %%
sns.histplot(data=iris, x=iris['Sepal.Width'],color='white')
sns.rugplot(data=iris, x=iris['Sepal.Width'])
# Out:
# <Axes: xlabel='Sepal.Width', ylabel='Count'>

# %%
# ***** displot
sns.displot(data=iris,x=iris['Sepal.Width'],col='Species',kde=True,rug=True)
plt.show()

# %%
t = [str(i)+'cylinder' for i in mtc.cyl.value_counts().sort_index().index]

plt.pie(mtc.cyl.value_counts().sort_index(),colors=['yellowgreen','lightskyblue','lightcoral'],autopct='%1.1f%%',labels=t)

plt.show()

# %%
l = [str(i)+'gear' for i in mtc.gear.value_counts().sort_index().index]
c = sns.color_palette('Accent',len(l))

plt.pie(mtc.gear.value_counts().sort_index(),colors=c,autopct='%1.1f%%',labels=l,explode=[0,.1,0],shadow=True,startangle=90)
plt.show()

# %%
sns.violinplot(iris,x='Species',y='Petal.Width',hue='Species',legend='full')
plt.show()

# %%
mc = mtc.iloc[:,:4]

# %%
sns.pairplot(mc,kind='reg',diag_kind='kde',corner=True,hue='cyl')
plt.show()

# %%
ci = iris[iris.columns[:-1].to_list()].corr()

# %%
sns.heatmap(ci,annot=True)
plt.show()

# %%
mask = np.zeros_like(ci, dtype=bool)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(ci,annot=True,mask=mask,cmap='coolwarm',annot_kws={'size':10},vmin=-1,vmax=1,cbar={'shrink':.4},linewidths=.5)
plt.show()

# %%
df=data('airquality')
sns.barplot(df.isnull().sum())
plt.ylabel('missing values')
plt.show()

# %%
f = df.groupby('Month')['Ozone'].transform('mean')
df['Ozone']=df['Ozone'].fillna(f)
df['Solar.R']=df['Solar.R'].fillna(df['Solar.R'].mean())
df.isnull().sum()
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Temp       0
# Month      0
# Day        0
# dtype: int64
